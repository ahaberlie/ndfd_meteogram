# %%
from netCDF4 import Dataset
import datetime
import numpy as np
from scipy.interpolate import UnivariateSpline

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (25, 10)

nc = Dataset("../data/NDFD_NWS_CONUS_conduit_2p5km_20160829_1800.grib2.nc")

stime = datetime.datetime(2016, 8, 29, 18, 0)

def kelvin2deg(K):
    
    return np.array(K * 9/5 - 459.67)

# %%
td = nc.variables['Dewpoint_temperature_surface']
t = nc.variables['Temperature_surface'] 
wsp = nc.variables['Wind_speed_surface']

dewpoint = kelvin2deg(td[:,120,200])
temp = kelvin2deg(t[:,120,200])
wspeed = np.array(wsp[:,120,200])


hours = np.array(nc.variables['time'][:])

td_smooth = UnivariateSpline(hours, dewpoint, s=1)
t_smooth = UnivariateSpline(hours, temp, s=1)
wsp_smooth = UnivariateSpline(hours, wspeed, s=1)

hours = np.linspace(np.min(hours), np.max(hours), 500)

time = np.array([stime + datetime.timedelta(hours=h) for h in hours])


plt.plot(time, td_smooth(hours), "g-")
plt.plot(time, t_smooth(hours), "r-")


plt.ylim(np.min(dewpoint) - 10, np.max(temp) + 10 )
# Out:
# (58.990020751953125, 100.04995727539063)

# %%
plt.plot(time, wsp_smooth(hours), "m-")

plt.ylim(np.min(wspeed) - 10, np.max(wspeed) + 10 )
# Out:
# (-9.5, 13.099999904632568)

# %%
plt.plot(np.array(nc.variables['time'][:]), dewpoint)
plt.plot(np.array(nc.variables['time'][:]), temp)
plt.ylim(60, 90)
# Out:
# (60, 90)

# %%
dp
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float32 Dewpoint_temperature_surface(time, y, x)
#     long_name: Dewpoint temperature @ Ground or water surface
#     units: K
#     description: Dewpoint temperature
#     missing_value: nan
#     grid_mapping: LambertConformal_Projection
#     coordinates: time y x
#     Grib_Variable_Id: VAR_0-0-6_L1
#     Grib2_Parameter: [0 0 6]
#     Grib2_Parameter_Discipline: Meteorological products
#     Grib2_Parameter_Category: Temperature
#     Grib2_Parameter_Name: Dewpoint temperature
#     Grib2_Level_Type: Ground or water surface
#     Grib2_Generating_Process_Type: Forecast
# unlimited dimensions:
# current shape = (42, 480, 728)
# filling off

# %%
time.shape
# Out:
# (20,)
