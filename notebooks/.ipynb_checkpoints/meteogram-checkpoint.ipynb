# %%
from netCDF4 import Dataset
import datetime
import numpy as np
from scipy.interpolate import UnivariateSpline
from matplotlib.dates import date2num 
import matplotlib.dates as mdates
from pytz import timezone

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (18, 12)
plt.rcParams['timezone'] = timezone("US/Central")

nc = Dataset("../data/NDFD_NWS_CONUS_conduit_2p5km_20160830_2200.grib2.nc")


stime = timezone('UTC').localize(datetime.datetime(2016, 8, 30, 22, 0))

def kelvin2deg(K):
    
    return np.array(K * 9/5 - 459.67)

print(nc.variables['lat'][338,394], nc.variables['lon'][338,394])
# Out:
# 42.4420438977 -88.7545294101

# %%
from matplotlib.ticker import AutoMinorLocator
import matplotlib.patheffects as PathEffects

minorLocator = AutoMinorLocator(12)

td = nc.variables['Dewpoint_temperature_surface']
t = nc.variables['Temperature_surface'] 
wsp = nc.variables['Wind_speed_surface']
wdir = nc.variables['Wind_direction_from_which_blowing_surface']
tcld = nc.variables['Total_cloud_cover_surface']
rhmd = nc.variables['Relative_humidity_surface']

ppop = nc.variables['Total_precipitation_surface_12_Hour_Accumulation_probability_above_0p254']


myFmt = mdates.DateFormatter('%m/%d\n%I:%M %p')

dewpoint = kelvin2deg(td[:,338,394])
temp = kelvin2deg(t[:,338,394])
wspeed = np.array(wsp[:,338,394])
wdirection = np.deg2rad(wdir[:,338,394])
percentcloud = np.array(tcld[:,338,394])
relativehumidity = np.array(rhmd[:,338,394])
precip_prob = np.array(ppop[:,338,394])

u = -wspeed * np.sin(wdirection)
v = -wspeed * np.cos(wdirection)

hrs = np.array(nc.variables['time5'][:], dtype=int)
hrs_ppop = np.array(nc.variables['time'][:], dtype=int)

hours = np.array(list(range(np.min(hrs), np.max(hrs)+1)))

td_smooth = UnivariateSpline(hrs, dewpoint, s=1)
t_smooth = UnivariateSpline(hrs, temp, s=1)
wsp_smooth = UnivariateSpline(hrs, wspeed, s=1)
tcld_smooth = UnivariateSpline(hrs, percentcloud, s=1)
rlmd_smooth = UnivariateSpline(hrs, relativehumidity, s=1)
ppop_smooth = UnivariateSpline(hrs_ppop, precip_prob, s=1)

time = np.array([stime + datetime.timedelta(hours=h) for h in hrs.astype(float)])
time_smooth = np.array([stime + datetime.timedelta(hours=h) for h in hours.astype(float)])

ax1 = plt.subplot(3, 1, 1)

max_temp = int(np.max(t_smooth(hours)))

ax1.plot(time_smooth, t_smooth(hours), "r-", linewidth=2, label="Temperature")

for h in hours[1:-1:5]:
    ax1.text(time_smooth[h] - datetime.timedelta(hours=2), t_smooth(h-1)+2, str(int(t_smooth(h))), color='r', fontsize=12,
            path_effects=[PathEffects.withStroke(linewidth=3, foreground="w")])
    ax1.plot(time_smooth[h] - datetime.timedelta(hours=1), t_smooth(h), "r.", markersize=8)
    
    ax1.text(time_smooth[h] - datetime.timedelta(hours=2), td_smooth(h)-4, str(int(td_smooth(h))), color='g', fontsize=12,
            path_effects=[PathEffects.withStroke(linewidth=3, foreground="w")])
    ax1.plot(time_smooth[h] - datetime.timedelta(hours=1), td_smooth(h), "g.", markersize=8)
    

ax1.plot(time_smooth, td_smooth(hours), "g-", linewidth=2, label="Dew Point")

ax1.legend(loc='upper center', bbox_to_anchor=(0.5, 1.25),
          ncol=3, fancybox=True, shadow=True)

ax1.set_ylim(np.min(dewpoint) - 5, np.max(temp) + 5 )

ax1.grid(b=True, which='major', color='k', linestyle='-')
ax1.grid(b=True, which='minor', color='k', linestyle=':')
ax1.minorticks_on()

ax1.set_xticklabels([])

plt.setp(ax1.get_xticklabels(), visible=False)

ax2 = plt.subplot(3, 1, 2, sharex=ax1)

ax2.plot(time_smooth, wsp_smooth(hours), linewidth=2, color="magenta", label="Wind Speed")
ax2.barbs(date2num(time_smooth[hrs-1]), wsp_smooth(hrs), u, v)

for h in hours[1:-1:5]:
    ax2.text(time_smooth[h] - datetime.timedelta(hours=2), wsp_smooth(h-1)-1, str(int(wsp_smooth(h))), color='m', fontsize=12,
            path_effects=[PathEffects.withStroke(linewidth=3, foreground="w")])
    ax2.plot(time_smooth[h] - datetime.timedelta(hours=1), wsp_smooth(h), "m.", markersize=8)

ax2.grid(b=True, which='major', color='k', linestyle='-')
ax2.grid(b=True, which='minor', color='k', linestyle=':')
ax2.minorticks_on()

ax2.legend(loc='upper center', bbox_to_anchor=(0.5, 1.25),
          ncol=3, fancybox=True, shadow=True)

ax2.set_ylim(0, np.max(wspeed) + 4)

plt.setp(ax2.get_xticklabels(), visible=False)

ax3 = plt.subplot(3, 1, 3, sharex=ax1)

ax3.grid(b=True, which='major', color='k', linestyle='-')
ax3.grid(b=True, which='minor', color='k', linestyle=':')
ax3.minorticks_on()



ax3.xaxis.set_minor_locator(minorLocator)

ax3.xaxis.set_major_formatter(myFmt)

ax3.xaxis.set_minor_locator(minorLocator)

ax3.plot(time_smooth, tcld_smooth(hours), linewidth=2, color="blue", label="Percent Sky Cover")

ax3.plot(time_smooth, rlmd_smooth(hours), linewidth=2, color="darkgreen", label="Relative Humidity")

ax3.plot(time_smooth, ppop_smooth(hours), linewidth=2, color="brown", label="Precipitation Probability")

for h in hours[1:-1:6]:
    ax3.text(time_smooth[h] - datetime.timedelta(hours=2), tcld_smooth(h-1)+2, str(int(tcld_smooth(h)))+"%", color='b', fontsize=12,
            path_effects=[PathEffects.withStroke(linewidth=3, foreground="w")])
    ax3.plot(time_smooth[h] - datetime.timedelta(hours=1), tcld_smooth(h), "b.", markersize=8)
    
    ax3.text(time_smooth[h] - datetime.timedelta(hours=2), rlmd_smooth(h)-4, str(int(rlmd_smooth(h)))+"%",
             color="darkgreen", fontsize=12,
            path_effects=[PathEffects.withStroke(linewidth=3, foreground="w")])
    
    ax3.plot(time_smooth[h] - datetime.timedelta(hours=1), rlmd_smooth(h), color="darkgreen", marker='.', markersize=8)
    
    ax3.text(time_smooth[h] - datetime.timedelta(hours=2), ppop_smooth(h)-4, 
             str(int(ppop_smooth(h)))+"%", color='brown', fontsize=12,
             path_effects=[PathEffects.withStroke(linewidth=3, foreground="w")])
    
    ax3.plot(time_smooth[h] - datetime.timedelta(hours=1), ppop_smooth(h), color='brown', marker='.', markersize=8)

ax3.legend(loc='upper center', bbox_to_anchor=(0.5, 1.25),
          ncol=3, fancybox=True, shadow=True)

ax3.set_ylim(-10, 100)

plt.subplots_adjust(hspace = .3)

# %%
plt.plot(hrs_ppop, precip_prob, linewidth=2, color="brown", label="Precipitation Probability")

# %%
time
# Out:
# array([datetime.datetime(2016, 8, 30, 23, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 0, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 1, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 2, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 3, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 4, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 5, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 6, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 7, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 8, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 9, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 10, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 11, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 12, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 13, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 14, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 15, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 16, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 17, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 18, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 19, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 20, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 21, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 22, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 8, 31, 23, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 1, 0, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 1, 1, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 1, 2, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 1, 3, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 1, 4, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 1, 5, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 1, 6, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 1, 7, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 1, 8, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 1, 9, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 1, 10, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 1, 12, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 1, 15, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 1, 18, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 1, 21, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 2, 0, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 2, 3, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 2, 6, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 2, 9, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 2, 12, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 2, 15, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 2, 18, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 2, 21, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 3, 0, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 3, 6, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 3, 12, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 3, 18, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 4, 0, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 4, 6, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 4, 12, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 4, 18, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 5, 0, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 5, 6, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 5, 12, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 5, 18, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 6, 0, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 6, 6, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 6, 12, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 6, 18, 0, tzinfo=<UTC>),
#        datetime.datetime(2016, 9, 7, 0, 0, tzinfo=<UTC>)], dtype=object)

# %%
plt.plot(np.array(nc.variables['time5'][:]), dewpoint)
plt.plot(np.array(nc.variables['time5'][:]), temp)
plt.ylim(45, 90)
# Out:
# (45, 90)

# %%
dp
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float32 Dewpoint_temperature_surface(time, y, x)
#     long_name: Dewpoint temperature @ Ground or water surface
#     units: K
#     description: Dewpoint temperature
#     missing_value: nan
#     grid_mapping: LambertConformal_Projection
#     coordinates: time y x
#     Grib_Variable_Id: VAR_0-0-6_L1
#     Grib2_Parameter: [0 0 6]
#     Grib2_Parameter_Discipline: Meteorological products
#     Grib2_Parameter_Category: Temperature
#     Grib2_Parameter_Name: Dewpoint temperature
#     Grib2_Level_Type: Ground or water surface
#     Grib2_Generating_Process_Type: Forecast
# unlimited dimensions:
# current shape = (42, 480, 728)
# filling off

# %%
time.shape
# Out:
# (20,)
